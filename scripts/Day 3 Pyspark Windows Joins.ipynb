# %%
df_o= (spark.read
.option("header", "true")
.option("inferSchema", "true").csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv"))

# %%
df_n= (spark.read
.option("header", "true")
.option("inferSchema", "true").csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv"))

# %%
df_o_products = df_o.select("product_id","category_id","category_code","brand","price").dropDuplicates(["product_id"]);
df_o_products.count()
# Out:
# 166794

# %%
df_o_users = df_o.select("user_id").dropDuplicates(["user_id"])
df_o_users.count()
# Out:
# 3022290

# %%
df_o_events = df_o.select("event_time","event_type","product_id","user_id","user_session");

# %%
df_o_events.count()
# Out:
# 42448764

# %%
df_o_join = df_o_events.join(df_o_products, on="product_id", how="left_outer") \
            .join(df_o_users, on="user_id", how="left_outer");
df_o_join.count()
# Out:
# 42448764

# %%
df_o.orderBy("event_time","user_id").show(10)
# Out:
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code|   brand|  price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |2019-10-01 00:00:00|      view|  44600062|2103807459595387724|                NULL|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|
# |2019-10-01 00:00:00|      view|   3900821|2053013552326770905|appliances.enviro...|    aqua|   33.2|554748717|9333dfbd-b87a-470...|
# |2019-10-01 00:00:01|      view|  17200506|2053013559792632471|furniture.living_...|    NULL|  543.1|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:00:01|      view|   1307067|2053013558920217191|  computers.notebook|  lenovo| 251.74|550050854|7c90fc70-0e80-459...|
# |2019-10-01 00:00:04|      view|   1004237|2053013555631882655|electronics.smart...|   apple|1081.98|535871217|c6bd7419-2748-4c5...|
# |2019-10-01 00:00:05|      view|   1480613|2053013561092866779|   computers.desktop|  pulser| 908.62|512742880|0d0d91c2-c9c2-4e8...|
# |2019-10-01 00:00:08|      view|  31500053|2053013558031024687|                NULL|luminarc|  41.16|550978835|6280d577-25c8-414...|
# |2019-10-01 00:00:08|      view|  17300353|2053013553853497655|                NULL|   creed| 380.96|555447699|4fe811e9-91de-46d...|
# |2019-10-01 00:00:10|      view|  28719074|2053013565480109009|  apparel.shoes.keds|   baden| 102.71|520571932|ac1cd4e5-a3ce-422...|
# |2019-10-01 00:00:11|      view|   1005011|2053013555631882655|electronics.smart...| samsung| 900.64|530282093|50a293fb-5940-41b...|
# +-------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# only showing top 10 rows

# %%
df_n.show(10)
# Out:
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code|   brand| price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+
# |2019-11-01 00:00:00|      view|   1003461|2053013555631882655|electronics.smart...|  xiaomi|489.07|520088904|4d3b30da-a5e4-49d...|
# |2019-11-01 00:00:00|      view|   5000088|2053013566100866035|appliances.sewing...|  janome|293.65|530496790|8e5f4f83-366c-4f7...|
# |2019-11-01 00:00:01|      view|  17302664|2053013553853497655|                NULL|   creed| 28.31|561587266|755422e7-9040-477...|
%%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

window = Window.partitionBy("user_id").orderBy("event_time")
df_o.withColumn("cumulative_events", F.count("*").over(window)).show(20)
# Out:
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+-----------------+
# |         event_time|event_type|product_id|        category_id|       category_code|   brand| price|  user_id|        user_session|cumulative_events|
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+-----------------+
# |2019-10-09 10:30:19|      view|  17301541|2053013553853497655|                NULL|    NULL|162.17|205053188|e1eadbc6-aef5-4cf...|                1|
# |2019-10-09 10:30:44|      view|  17301541|2053013553853497655|                NULL|    NULL|162.17|205053188|e1eadbc6-aef5-4cf...|                2|
# |2019-10-07 06:23:01|      view|  16200119|2053013556344914381|   kids.fmcg.diapers|   moony| 18.47|222907508|cb653adc-46a2-4d9...|                1|
# |2019-10-07 06:26:23|      view|  16200162|2053013556344914381|   kids.fmcg.diapers|   moony| 18.47|222907508|cb653adc-46a2-4d9...|                2|
# |2019-10-08 14:29:09|      view|   6200883|2053013552293216471|appliances.enviro...|elenberg| 46.31|244673419|e2f0524c-bfc4-4c6...|                1|
# |2019-10-12 10:15:48|      view|  17300355|2053013553853497655|                NULL|   creed|240.16|257849716|71e76013-465a-464...|                1|
# |2019-10-22 22:05:40|      view|   3900896|2053013552326770905|appliances.enviro...|   klima|  77.2|266203246|c83d6f3d-2973-411...|                1|
# |2019-10-24 01:14:36|      view|   3900896|2053013552326770905|appliances.enviro...|   klima|  77.2|266203246|56944410-059f-4f0...|                2|
# |2019-10-06 11:29:22|      view|  22700574|2053013556168753601|                NULL|    NULL| 88.81|278272605|e4cd7037-61d8-461...|                1|
# |2019-10-06 11:30:58|      view|  22700129|2053013556168753601|                NULL|   stels| 66.93|278272605|0a20874c-c88c-462...|                2|
# |2019-10-06 11:31:53|      view|  22700078|2053013556168753601|                NULL|   stels|180.18|278272605|0a20874c-c88c-462...|                3|
# |2019-10-06 11:34:45|      view|  22700078|2053013556168753601|                NULL|   stels|180.18|278272605|0a20874c-c88c-462...|                4|
# |2019-10-06 16:56:05|      view|  22700078|2053013556168753601|                NULL|   stels|180.18|278272605|ef4dccc3-e1ca-4bd...|                5|
# |2019-10-25 09:31:11|      view|   1004209|2053013555631882655|electronics.smart...| samsung| 88.79|279209491|fd193b03-0327-46e...|                1|
# |2019-10-23 01:01:59|      view|  26402687|2053013563651392361|                NULL|    NULL|375.97|284628126|56de7dcd-ad20-42e...|                1|
# |2019-10-27 19:35:43|      view|  28717970|2053013565782098913|       apparel.shoes|  rieker| 86.23|299004865|8c8ebbd4-0e10-44c...|                1|
# |2019-10-30 16:17:28|      view|   1307350|2053013558920217191|  computers.notebook|    acer|514.79|301573329|1cdccb65-48e7-4b9...|                1|
# |2019-10-30 16:18:11|      view|   1307350|2053013558920217191|  computers.notebook|    acer|514.79|301573329|1cdccb65-48e7-4b9...|                2|
# |2019-10-30 16:18:19|      view|   1307361|2053013558920217191|  computers.notebook|  lenovo| 420.6|301573329|1cdccb65-48e7-4b9...|                3|
# |2019-10-30 16:20:12|      view|   1307071|2053013558920217191|  computers.notebook|    acer|643.26|301573329|1cdccb65-48e7-4b9...|                4|
# +-------------------+----------+----------+-------------------+--------------------+--------+------+---------+--------------------+-----------------+
# only showing top 20 rows

# %%
revenue = df_o.filter(F.col("event_type") == "purchase") \
    .groupBy("product_id", "product_name") \
    .agg(F.sum("price").alias("revenue")) \
    .orderBy(F.desc("revenue")).limit(5)
